# %%
# run this cell to connect to kaggle API via .json file
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3cab104b-df72-4618-866d-5ac1306117cd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3cab104b-df72-4618-866d-5ac1306117cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (2).json
# {'kaggle.json': b'{"username":"chidambarjoshi","key":"baccbcefbe54dd3f3ce32117fcba6634"}'}

# %%
# Install Kaggle API client
# !pip install -q kaggle

# %%
# kaggle API expects this to be in ~/.kaggle 
# !mkdir -p ~/.kaggle 
# !cp kaggle.json ~/.kaggle 

# !chmod 600 ~/.kaggle/kaggle.json

# %%
# creating directory and changing pwd
# !mkdir dog_dataset
# %cd dog_dataset
# Out:
# mkdir: cannot create directory ‘dog_dataset’: File exists
# /content/dog_dataset

# %%
# searching dataset
# !kaggle datasets list -s dogbreedidfromcomp
# Out:
# ref                                title                    size  lastUpdated          downloadCount  voteCount  usabilityRating
# ---------------------------------  ----------------------  -----  -------------------  -------------  ---------  ---------------
# catherinehorng/dogbreedidfromcomp  dog-breed-id-from-comp  691MB  2020-06-26 03:09:05           1475          6  0.1764706

# %%
#dowloading dataset
# !kaggle datasets download catherinehorng/dogbreedidfromcomp
# %cd ..
# Out:
# Downloading dogbreedidfromcomp.zip to /content/dog_dataset
#  99% 682M/691M [00:04<00:00, 129MB/s]
# 100% 691M/691M [00:04<00:00, 155MB/s]
# /content

# %%
#unzip and remove unusable files
# !unzip dog_dataset/dogbreedidfromcomp.zip -d dog_dataset
# !rm dog_dataset/dogbreedidfromcomp.zip
# !rm dog_dataset/sample_submission.csv
# Out:
# Archive:  dog_dataset/dogbreedidfromcomp.zip
# replace dog_dataset/labels.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
#importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tqdm import tqdm   # used for creating progress meters/bars
from keras.preprocessing import image
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten, Conv2D , MaxPool2D
from tensorflow.keras.optimizers import Adam

# %%
# Read labels.csv file and checking shape and records

labels_all = pd.read_csv('/content/dog_dataset/labels.csv')
print(labels_all.shape)
labels_all.head()
# Out:
# (10222, 2)
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
# visualize number of each breeds
breeds_all  = labels_all['breed']
breed_counts = breeds_all.value_counts()
breed_counts.head()
# Out:
# scottish_deerhound      126
# maltese_dog             117
# afghan_hound            116
# entlebucher             115
# bernese_mountain_dog    114
# Name: breed, dtype: int64

# %%
# selecting first 3 breeds(computational limitations)
CLASS_NAMES = ['scottish_deerhound','maltese_dog','afghan_hound']
labels = labels_all[(labels_all['breed'].isin(CLASS_NAMES))].reset_index()
labels.head()
# Out:
#    index                                id               breed
# 0      9  0042188c895a2f14ef64a918ed9c7b64  scottish_deerhound
# 1     12  00693b8bc2470375cc744a6391d397ec         maltese_dog
# 2     79  01e787576c003930f96c966f9c3e1d44  scottish_deerhound
# 3     90  022b34fd8734b39995a9f38a4f3e7b6b         maltese_dog
# 4    146  0379145880ad3978f9b80f0dc2c03fba        afghan_hound

# %%
# Creating numpy matrix with zeros
X_data = np.zeros((len(labels),224,224,3),dtype='float32')

#One hot encoding
Y_data = label_binarize(labels['breed'],classes=CLASS_NAMES)

#reading and converting images to numpy array and normalizing dataset
for i in tqdm(range(len(labels))):
  img = image.load_img('dog_dataset/train/%s.jpg' % labels['id'][i],target_size=(224,224))
  img = image.img_to_array(img)
  x = np.expand_dims(img.copy(),axis=0)
  X_data[i] = x/255.0


# printing train image and one hot encode shape and size
print('\n Train Images Shape:',X_data.shape,'size: {:,}'.format(X_data.size))
print('One-hot encoded output shape:',Y_data.shape,'size: {:,}'.format(Y_data.size))

 #NOTE:  shape -> 359 images , 224*224 is the size and 3 is channels(RGB) colored images
# Out:
# 100%|██████████| 359/359 [00:01<00:00, 209.52it/s]
#  Train Images Shape: (359, 224, 224, 3) size: 54,039,552
# One-hot encoded output shape: (359, 3) size: 1,077

# %%
# Building the model
# Note: hyperparameter tuning-> Changing the no. of filters and parameters to obtain higher accuracy output
# conv2D is used to create convolutional kernel with i/p layer to produce o/p tensor
# Dense layer produces the o/p as the cross product of input and kernel

model = Sequential()

model.add(Conv2D(filters=64,kernel_size=(5,5),activation='relu',input_shape=(224,224,3)))
model.add(MaxPool2D(pool_size=(2,2)))  # findouts max dominant feature in a 2*2 matrix(window defined by poolsize)

model.add(Conv2D(filters=32,kernel_size=(3,3),activation='relu',kernel_regularizer='l2'))
model.add(MaxPool2D(pool_size=(2,2)))  

model.add(Conv2D(filters=16,kernel_size=(7,7),activation='relu',kernel_regularizer='l2'))
model.add(MaxPool2D(pool_size=(2,2)))  

model.add(Conv2D(filters=8,kernel_size=(5,5),activation='relu',kernel_regularizer='l2'))
model.add(MaxPool2D(pool_size=(2,2)))  

model.add(Flatten())  #flattens input and creates 1D output
model.add(Dense(128,activation='relu',kernel_regularizer='l2'))
model.add(Dense(64,activation='relu',kernel_regularizer='l2'))

#in a multiclass classification, generally activation func will be softmax
model.add(Dense(len(CLASS_NAMES),activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer=Adam(0.0001),metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 220, 220, 64)      4864
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 64)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 108, 108, 32)      18464
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 16)        25104
#
#  max_pooling2d_2 (MaxPooling  (None, 24, 24, 16)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 20, 20, 8)         3208
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 8)        0
#  2D)
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 128)               102528
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 162,619
# Trainable params: 162,619
# Non-trainable params: 0
# _________________________________________________________________

# %%
# splitting the data set into training and testing 
X_train_and_val, X_test, Y_train_and_val, Y_test = train_test_split(X_data,Y_data,test_size=0.1)

#splitting training dataset into training and validation datasets
X_train,X_val,Y_train,Y_val = train_test_split(X_train_and_val,Y_train_and_val,test_size=0.2)

# %%
#training and model
epochs = 100
batch_size = 128

history = model.fit(X_train, Y_train, batch_size = batch_size, epochs=epochs, validation_data=(X_val,Y_val))

# during the epochs we can see how the model is performing by viewing the training and validation accuracy
# Out:
# Epoch 1/100
# 3/3 [==============================] - 45s 9s/step - loss: 4.9045 - accuracy: 0.3023 - val_loss: 4.8703 - val_accuracy: 0.3538
# Epoch 2/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.8675 - accuracy: 0.3062 - val_loss: 4.8363 - val_accuracy: 0.3538
# Epoch 3/100
# 3/3 [==============================] - 37s 11s/step - loss: 4.8345 - accuracy: 0.3062 - val_loss: 4.8031 - val_accuracy: 0.3538
# Epoch 4/100
# 3/3 [==============================] - 33s 9s/step - loss: 4.8019 - accuracy: 0.3062 - val_loss: 4.7704 - val_accuracy: 0.3538
# Epoch 5/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.7696 - accuracy: 0.3062 - val_loss: 4.7384 - val_accuracy: 0.3538
# Epoch 6/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.7393 - accuracy: 0.3062 - val_loss: 4.7075 - val_accuracy: 0.3538
# Epoch 7/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.7081 - accuracy: 0.3062 - val_loss: 4.6772 - val_accuracy: 0.3538
# Epoch 8/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.6763 - accuracy: 0.3062 - val_loss: 4.6468 - val_accuracy: 0.3538
# Epoch 9/100
# 3/3 [==============================] - 33s 9s/step - loss: 4.6452 - accuracy: 0.3062 - val_loss: 4.6169 - val_accuracy: 0.3538
# Epoch 10/100
# 3/3 [==============================] - 40s 12s/step - loss: 4.6163 - accuracy: 0.3062 - val_loss: 4.5871 - val_accuracy: 0.3538
# Epoch 11/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.5860 - accuracy: 0.3062 - val_loss: 4.5574 - val_accuracy: 0.3538
# Epoch 12/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.5551 - accuracy: 0.3062 - val_loss: 4.5276 - val_accuracy: 0.3538
# Epoch 13/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.5248 - accuracy: 0.3062 - val_loss: 4.4979 - val_accuracy: 0.3538
# Epoch 14/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.4958 - accuracy: 0.3062 - val_loss: 4.4685 - val_accuracy: 0.3538
# Epoch 15/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.4658 - accuracy: 0.3062 - val_loss: 4.4405 - val_accuracy: 0.3538
# Epoch 16/100
# 3/3 [==============================] - 35s 9s/step - loss: 4.4362 - accuracy: 0.3062 - val_loss: 4.4132 - val_accuracy: 0.3538
# Epoch 17/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.4085 - accuracy: 0.3062 - val_loss: 4.3855 - val_accuracy: 0.3538
# Epoch 18/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.3805 - accuracy: 0.3062 - val_loss: 4.3584 - val_accuracy: 0.3538
# Epoch 19/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.3529 - accuracy: 0.3140 - val_loss: 4.3316 - val_accuracy: 0.3538
# Epoch 20/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.3257 - accuracy: 0.3411 - val_loss: 4.3051 - val_accuracy: 0.3692
# Epoch 21/100
# 3/3 [==============================] - 35s 9s/step - loss: 4.2988 - accuracy: 0.3876 - val_loss: 4.2789 - val_accuracy: 0.3846
# Epoch 22/100
# 3/3 [==============================] - 35s 9s/step - loss: 4.2724 - accuracy: 0.4496 - val_loss: 4.2526 - val_accuracy: 0.4308
# Epoch 23/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.2456 - accuracy: 0.4729 - val_loss: 4.2257 - val_accuracy: 0.4154
# Epoch 24/100
# 3/3 [==============================] - 40s 9s/step - loss: 4.2181 - accuracy: 0.5000 - val_loss: 4.1975 - val_accuracy: 0.3846
# Epoch 25/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.1900 - accuracy: 0.4186 - val_loss: 4.1694 - val_accuracy: 0.3077
# Epoch 26/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.1637 - accuracy: 0.3295 - val_loss: 4.1416 - val_accuracy: 0.3538
# Epoch 27/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.1400 - accuracy: 0.3062 - val_loss: 4.1158 - val_accuracy: 0.3538
# Epoch 28/100
# 3/3 [==============================] - 41s 9s/step - loss: 4.1176 - accuracy: 0.3062 - val_loss: 4.0908 - val_accuracy: 0.3538
# Epoch 29/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.0930 - accuracy: 0.3062 - val_loss: 4.0660 - val_accuracy: 0.3538
# Epoch 30/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.0654 - accuracy: 0.3062 - val_loss: 4.0424 - val_accuracy: 0.3538
# Epoch 31/100
# 3/3 [==============================] - 34s 9s/step - loss: 4.0393 - accuracy: 0.3140 - val_loss: 4.0186 - val_accuracy: 0.3538
# Epoch 32/100
# 3/3 [==============================] - 37s 9s/step - loss: 4.0136 - accuracy: 0.3217 - val_loss: 3.9943 - val_accuracy: 0.2923
# Epoch 33/100
# 3/3 [==============================] - 35s 9s/step - loss: 3.9885 - accuracy: 0.3411 - val_loss: 3.9707 - val_accuracy: 0.3077
# Epoch 34/100
# 3/3 [==============================] - 34s 9s/step - loss: 3.9644 - accuracy: 0.4031 - val_loss: 3.9469 - val_accuracy: 0.3538
# Epoch 35/100
# 3/3 [==============================] - 34s 9s/step - loss: 3.9405 - accuracy: 0.4419 - val_loss: 3.9255 - val_accuracy: 0.3692
# Epoch 36/100
# 3/3 [==============================] - 34s 9s/step - loss: 3.9183 - accuracy: 0.4651 - val_loss: 3.9052 - val_accuracy: 0.3692
# Epoch 37/100
# 3/3 [==============================] - 34s 9s/step - loss: 3.8966 - accuracy: 0.4806 - val_loss: 3.8836 - val_accuracy: 0.3538
# Epoch 38/100
# 3/3 [==============================] - 34s 9s/step - loss: 3.8738 - accuracy: 0.5155 - val_loss: 3.8598 - val_accuracy: 0.3692
# Epoch 39/100
# 3/3 [==============================] - 34s 9s/step - loss: 3.8488 - accuracy: 0.5039 - val_loss: 3.8331 - val_accuracy: 0.4154
# Epoch 40/100
# 3/3 [==============================] - 35s 9s/step - loss: 3.8239 - accuracy: 0.4457 - val_loss: 3.8072 - val_accuracy: 0.3692
# Epoch 41/100
# 3/3 [==============================] - 34s 9s/step - loss: 3.8008 - accuracy: 0.4070 - val_loss: 3.7842 - val_accuracy: 0.3846
# Epoch 42/100
# 3/3 [==============================] - 34s 9s/step - loss: 3.7780 - accuracy: 0.3837 - val_loss: 3.7623 - val_accuracy: 0.3846
# Epoch 43/100
# 3/3 [==============================] - 34s 9s/step - loss: 3.7547 - accuracy: 0.3837 - val_loss: 3.7408 - val_accuracy: 0.3385
# Epoch 44/100
# 3/3 [==============================] - 34s 9s/step - loss: 3.7317 - accuracy: 0.3721 - val_loss: 3.7192 - val_accuracy: 0.3538
# Epoch 45/100
# 3/3 [==============================] - 40s 12s/step - loss: 3.7088 - accuracy: 0.3876 - val_loss: 3.6992 - val_accuracy: 0.3692
# Epoch 46/100
# 3/3 [==============================] - 36s 9s/step - loss: 3.6860 - accuracy: 0.3837 - val_loss: 3.6784 - val_accuracy: 0.3538
# Epoch 47/100
# 3/3 [==============================] - 34s 9s/step - loss: 3.6631 - accuracy: 0.3760 - val_loss: 3.6577 - val_accuracy: 0.3538
# Epoch 48/100
# 3/3 [==============================] - 36s 9s/step - loss: 3.6397 - accuracy: 0.3760 - val_loss: 3.6358 - val_accuracy: 0.3538
# Epoch 49/100
# 3/3 [==============================] - 40s 12s/step - loss: 3.6166 - accuracy: 0.3760 - val_loss: 3.6138 - val_accuracy: 0.3692
# Epoch 50/100
# 3/3 [==============================] - 43s 11s/step - loss: 3.5927 - accuracy: 0.4109 - val_loss: 3.5928 - val_accuracy: 0.4308
# Epoch 51/100
# 3/3 [==============================] - 42s 11s/step - loss: 3.5689 - accuracy: 0.4225 - val_loss: 3.5683 - val_accuracy: 0.3538
# Epoch 52/100
# 3/3 [==============================] - 42s 11s/step - loss: 3.5481 - accuracy: 0.3682 - val_loss: 3.5473 - val_accuracy: 0.3538
# Epoch 53/100
# 3/3 [==============================] - 41s 11s/step - loss: 3.5447 - accuracy: 0.3605 - val_loss: 3.5359 - val_accuracy: 0.3538
# Epoch 54/100
# 3/3 [==============================] - 40s 10s/step - loss: 3.5424 - accuracy: 0.3605 - val_loss: 3.5183 - val_accuracy: 0.3538
# Epoch 55/100
# 3/3 [==============================] - 38s 10s/step - loss: 3.5069 - accuracy: 0.3605 - val_loss: 3.4871 - val_accuracy: 0.5231
# Epoch 56/100
# 3/3 [==============================] - 38s 10s/step - loss: 3.4609 - accuracy: 0.5310 - val_loss: 3.4916 - val_accuracy: 0.5077
# Epoch 57/100
# 3/3 [==============================] - 39s 11s/step - loss: 3.4584 - accuracy: 0.4767 - val_loss: 3.4635 - val_accuracy: 0.5231
# Epoch 58/100
# 3/3 [==============================] - 40s 11s/step - loss: 3.4264 - accuracy: 0.5736 - val_loss: 3.4233 - val_accuracy: 0.4923
# Epoch 59/100
# 3/3 [==============================] - 40s 11s/step - loss: 3.3969 - accuracy: 0.4535 - val_loss: 3.4071 - val_accuracy: 0.3692
# Epoch 60/100
# 3/3 [==============================] - 40s 11s/step - loss: 3.4010 - accuracy: 0.3798 - val_loss: 3.3848 - val_accuracy: 0.3692
# Epoch 61/100
# 3/3 [==============================] - 49s 11s/step - loss: 3.3709 - accuracy: 0.4147 - val_loss: 3.3625 - val_accuracy: 0.5077
# Epoch 62/100
# 3/3 [==============================] - 40s 11s/step - loss: 3.3395 - accuracy: 0.6124 - val_loss: 3.3611 - val_accuracy: 0.4308
# Epoch 63/100
# 3/3 [==============================] - 39s 10s/step - loss: 3.3321 - accuracy: 0.5581 - val_loss: 3.3365 - val_accuracy: 0.4615
# Epoch 64/100
# 3/3 [==============================] - 43s 11s/step - loss: 3.3026 - accuracy: 0.6279 - val_loss: 3.3030 - val_accuracy: 0.4462
# Epoch 65/100
# 3/3 [==============================] - 46s 12s/step - loss: 3.2667 - accuracy: 0.6395 - val_loss: 3.2793 - val_accuracy: 0.5077
# Epoch 66/100
# 3/3 [==============================] - 41s 10s/step - loss: 3.2498 - accuracy: 0.4922 - val_loss: 3.2629 - val_accuracy: 0.5077
# Epoch 67/100
# 3/3 [==============================] - 38s 10s/step - loss: 3.2178 - accuracy: 0.5698 - val_loss: 3.2711 - val_accuracy: 0.5385
# Epoch 68/100
# 3/3 [==============================] - 42s 12s/step - loss: 3.2109 - accuracy: 0.5620 - val_loss: 3.2733 - val_accuracy: 0.5077
# Epoch 69/100
# 3/3 [==============================] - 38s 10s/step - loss: 3.2053 - accuracy: 0.4806 - val_loss: 3.2442 - val_accuracy: 0.5385
# Epoch 70/100
# 3/3 [==============================] - 36s 10s/step - loss: 3.1587 - accuracy: 0.5736 - val_loss: 3.2246 - val_accuracy: 0.4769
# Epoch 71/100
# 3/3 [==============================] - 44s 12s/step - loss: 3.1790 - accuracy: 0.4380 - val_loss: 3.2493 - val_accuracy: 0.4000
# Epoch 72/100
# 3/3 [==============================] - 40s 11s/step - loss: 3.2209 - accuracy: 0.4031 - val_loss: 3.1577 - val_accuracy: 0.4923
# Epoch 73/100
# 3/3 [==============================] - 38s 10s/step - loss: 3.0947 - accuracy: 0.5349 - val_loss: 3.1584 - val_accuracy: 0.5077
# Epoch 74/100
# 3/3 [==============================] - 38s 10s/step - loss: 3.0788 - accuracy: 0.5233 - val_loss: 3.1237 - val_accuracy: 0.4615
# Epoch 75/100
# 3/3 [==============================] - 42s 12s/step - loss: 3.0598 - accuracy: 0.5698 - val_loss: 3.0934 - val_accuracy: 0.4462
# Epoch 76/100
# 3/3 [==============================] - 46s 10s/step - loss: 3.0506 - accuracy: 0.5310 - val_loss: 3.0700 - val_accuracy: 0.3846
# Epoch 77/100
# 3/3 [==============================] - 39s 11s/step - loss: 3.0097 - accuracy: 0.5930 - val_loss: 3.1007 - val_accuracy: 0.4462
# Epoch 78/100
# 3/3 [==============================] - 39s 10s/step - loss: 3.0333 - accuracy: 0.5194 - val_loss: 3.1670 - val_accuracy: 0.3846
# Epoch 79/100
# 3/3 [==============================] - 40s 11s/step - loss: 3.0608 - accuracy: 0.4496 - val_loss: 3.0683 - val_accuracy: 0.4923
# Epoch 80/100
# 3/3 [==============================] - 44s 12s/step - loss: 2.9478 - accuracy: 0.5814 - val_loss: 3.0392 - val_accuracy: 0.4615
# Epoch 81/100
# 3/3 [==============================] - 48s 14s/step - loss: 3.0343 - accuracy: 0.4806 - val_loss: 3.0528 - val_accuracy: 0.4154
# Epoch 82/100
# 3/3 [==============================] - 41s 11s/step - loss: 2.9902 - accuracy: 0.4845 - val_loss: 2.9932 - val_accuracy: 0.5692
# Epoch 83/100
# 3/3 [==============================] - 41s 11s/step - loss: 2.8947 - accuracy: 0.6124 - val_loss: 3.0320 - val_accuracy: 0.5231
# Epoch 84/100
# 3/3 [==============================] - 42s 11s/step - loss: 2.9292 - accuracy: 0.5581 - val_loss: 3.0632 - val_accuracy: 0.4462
# Epoch 85/100
# 3/3 [==============================] - 38s 10s/step - loss: 2.9587 - accuracy: 0.4729 - val_loss: 3.0606 - val_accuracy: 0.4308
# Epoch 86/100
# 3/3 [==============================] - 38s 10s/step - loss: 2.9506 - accuracy: 0.4690 - val_loss: 2.9822 - val_accuracy: 0.5231
# Epoch 87/100
# 3/3 [==============================] - 35s 9s/step - loss: 2.8653 - accuracy: 0.5581 - val_loss: 2.8860 - val_accuracy: 0.4462
# Epoch 88/100
# 3/3 [==============================] - 35s 10s/step - loss: 2.8494 - accuracy: 0.6047 - val_loss: 3.0230 - val_accuracy: 0.3231
# Epoch 89/100
# 3/3 [==============================] - 37s 10s/step - loss: 3.0816 - accuracy: 0.4109 - val_loss: 3.0046 - val_accuracy: 0.3231
# Epoch 90/100
# 3/3 [==============================] - 36s 9s/step - loss: 2.9846 - accuracy: 0.4496 - val_loss: 2.8539 - val_accuracy: 0.4462
# Epoch 91/100
# 3/3 [==============================] - 41s 12s/step - loss: 2.7860 - accuracy: 0.6628 - val_loss: 2.8894 - val_accuracy: 0.5385
# Epoch 92/100
# 3/3 [==============================] - 33s 9s/step - loss: 2.7928 - accuracy: 0.5504 - val_loss: 2.9398 - val_accuracy: 0.4923
# Epoch 93/100
# 3/3 [==============================] - 33s 9s/step - loss: 2.8161 - accuracy: 0.5388 - val_loss: 2.9121 - val_accuracy: 0.5538
# Epoch 94/100
# 3/3 [==============================] - 33s 9s/step - loss: 2.7747 - accuracy: 0.6047 - val_loss: 2.8756 - val_accuracy: 0.5231
# Epoch 95/100
# 3/3 [==============================] - 33s 9s/step - loss: 2.7682 - accuracy: 0.5504 - val_loss: 2.8392 - val_accuracy: 0.5077
# Epoch 96/100
# 3/3 [==============================] - 33s 9s/step - loss: 2.7450 - accuracy: 0.5581 - val_loss: 2.7921 - val_accuracy: 0.5231
# Epoch 97/100
# 3/3 [==============================] - 33s 9s/step - loss: 2.6933 - accuracy: 0.6240 - val_loss: 2.7715 - val_accuracy: 0.5692
# Epoch 98/100
# 3/3 [==============================] - 33s 9s/step - loss: 2.6716 - accuracy: 0.6744 - val_loss: 2.7568 - val_accuracy: 0.5538
# Epoch 99/100
# 3/3 [==============================] - 33s 9s/step - loss: 2.6619 - accuracy: 0.6860 - val_loss: 2.7362 - val_accuracy: 0.5231
# Epoch 100/100
# 3/3 [==============================] - 33s 9s/step - loss: 2.6486 - accuracy: 0.6899 - val_loss: 2.7222 - val_accuracy: 0.5231

# %%
# plot the history
plt.figure(figsize=(12,5))
plt.plot(history.history['accuracy'],color='r')
plt.plot(history.history['val_accuracy'],color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train','val'])

plt.show()

# %%
# accuracy calc
Y_pred = model.predict(X_test)
score = model.evaluate(X_test,Y_test)
print('Accuracy over the test set:\n',round((score[1]*100),2),'%')
# Out:
# 2/2 [==============================] - 1s 136ms/step - loss: 2.6481 - accuracy: 0.5556
# Accuracy over the test set:
#  55.56 %

# %%
# Plottig img to compare
plt.imshow(X_test[1,:,:,:])
plt.show()

#finding max value from prediction list and comparing org value vs predicted
print("Originally : ",labels['breed'][np.argmax(Y_test[1])])
print("Predicted : ",labels['breed'][np.argmax(Y_pred[1])])
# Out:
# Originally :  maltese_dog
# Predicted :  maltese_dog
